# %%
# Import the modules 
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read and display the CSV with Pandas
covid_df = pd.read_csv("Resources/Covid19_Confirmed_dataset.csv")
covid_df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
#  Delete the useless columns
covid_df.drop(["Lat", "Long"], axis = 1, inplace = True)
covid_df
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
# ...

# %%
# Aggregating the rows by the country
covid_df_aggregated = covid_df.groupby("Country/Region").sum()
covid_df_aggregated.drop(["Province/State"], axis = 1, inplace = True)
covid_df_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
# Visualizing data related to the Canada and China
covid_df_aggregated.loc["Canada"].plot()
covid_df_aggregated.loc["China"].plot()
plt.legend()

# %%
# Spread of the virus in the first 5 days
covid_df_aggregated.loc["China"][ : 5].plot()
# Out:
# <Axes: >

# %%
# Caculating the first derivative of the curve
covid_df_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
# Find maxmimum infection rate for China
covid_df_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
# Find maxmimum infection rate for the US
covid_df_aggregated.loc["US"].diff().max()
# Out:
# 36188.0

# %%
# Find maxmimum infection rate for Canada
covid_df_aggregated.loc["Canada"].diff().max()
# Out:
# 2778.0

# %%
# Find maximum infection rate for all of the countries
countries = list(covid_df_aggregated.index)

# Create an empty list
max_infection_rate = []

for i in countries:
    x = covid_df_aggregated.loc[i].diff().max()
    max_infection_rate.append(x)

covid_df_aggregated["max_infection_rate"] = max_infection_rate

covid_df_aggregated["max_infection_rate"]
# Out:
# Country/Region
# Afghanistan           232.0
# Albania                34.0
# Algeria               199.0
# Andorra                43.0
# Angola                  5.0
#                       ...
# West Bank and Gaza     66.0
# Western Sahara          4.0
# Yemen                   5.0
# Zambia                  9.0
# Zimbabwe                8.0
# Name: max_infection_rate, Length: 187, dtype: float64

# %%
# Create a new dataframe with only needed column
covid_df_updated = pd.DataFrame(covid_df_aggregated["max_infection_rate"])
covid_df_updated
# Out:
#                     max_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
# Importing the WorldHappinessReport.csv dataset
happiness_report = pd.read_csv("Resources/worldwide_happiness_report.csv")
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Drop the useless columns
happiness_report.drop(["Overall rank", "Score", "Generosity", "Perceptions of corruption"], axis = 1, inplace = True)
happiness_report
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %%
# Changing the indices of the dataframe
happiness_report.set_index("Country or region", inplace = True)
happiness_report
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %%
# Join two dataset we have prepared
data = covid_df_updated.join(happiness_report, how = "inner")
data
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
# Correlation matrix
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %%
# Plotting GDP vs maximum Infection rate
data["log_max_infection_rate"] = np.log(data["max_infection_rate"])

sns.scatterplot(data = data, x = "GDP per capita", y = "log_max_infection_rate")
plt.title("GDP per capita vs Maximum Infection Rate")
plt.xlabel("GDP per capita")
plt.ylabel("Maximum Infection Rate")
plt.show()

# %%
sns.regplot(data = data, x = "GDP per capita", y = "log_max_infection_rate")
# Out:
# <Axes: xlabel='GDP per capita', ylabel='log_max_infection_rate'>

# %%
# Plotting Social support vs maximum Infection rate
sns.scatterplot(data = data, x = "Social support", y = "log_max_infection_rate")
plt.title("Social support vs Maximum Infection Rate")
plt.xlabel("Social support")
plt.ylabel("Maximum Infection Rate")
plt.show()

# %%
sns.regplot(data = data, x = "Social support", y = "log_max_infection_rate")
# Out:
# <Axes: xlabel='Social support', ylabel='log_max_infection_rate'>

# %%
# Plotting Healthy life expectancy vs maximum Infection rate
sns.scatterplot(data = data, x = "Healthy life expectancy", y = "log_max_infection_rate")
plt.title("Healthy life expectancy vs Maximum Infection Rate")
plt.xlabel("Healthy life expectancy")
plt.ylabel("Maximum Infection Rate")
plt.show()

# %%
sns.regplot(data = data, x = "Healthy life expectancy", y = "log_max_infection_rate")
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='log_max_infection_rate'>

# %%
# Plotting Freedom to make life choices vs maximum Infection rate
sns.scatterplot(data = data, x = "Freedom to make life choices", y = "log_max_infection_rate")
plt.title("Freedom to make life choices vs Maximum Infection Rate")
plt.xlabel("Freedom to make life choices")
plt.ylabel("Maximum Infection Rate")
plt.show()

# %%
sns.regplot(data = data, x = "Freedom to make life choices", y = "log_max_infection_rate")
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='log_max_infection_rate'>
